# %% [markdown]
# <a href="https://colab.research.google.com/github/yuldoshovshohrux5701-glitch/SIA/blob/main/labarotoriya_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('24.csv')

# %%
df.head()
# Out:
#    year anzsic anzsic_descriptor                   variable1  variable2  \
# 0  2007    AA1       Agriculture              Carbon dioxide  Emissions
# 1  2007    AA1       Agriculture  Carbon dioxide equivalents  Emissions
# 2  2007    AA1       Agriculture                     Methane  Emissions
# 3  2007    AA1       Agriculture               Nitrous oxide  Emissions
# 4  2007    AA1       Agriculture          Hydrofluorocarbons  Emissions
#
#   category       units                   magnitude                  source  \
# 0    Total  Kilotonnes  Carbon dioxide equivalents  Environmental accounts
# 1    Total  Kilotonnes  Carbon dioxide equivalents  Environmental accounts
# 2    Total  Kilotonnes  Carbon dioxide equivalents  Environmental accounts
# 3    Total  Kilotonnes  Carbon dioxide equivalents  Environmental accounts
# 4    Total  Kilotonnes  Carbon dioxide equivalents  Environmental accounts
#
#    data_value
# 0     2583.37
# 1    44120.30
# 2    35447.31
# 3     6088.57
# ...
